# %%
import numpy as np
from pycaret.regression import *
import pandas as pd

data = pd.read_csv("vehicle-dataset-from-cardekho/car details v4.csv")

# convert data to normal
data['Price'] /= 81.28      # INR -> USD

data['Engine'] = data['Engine'].str.extract('(\d+)').astype(float)

data['Max Power (hp)'] = pd.to_numeric(data['Max Power'].str.extract(
    '(\d+\.?\d*)')[0], errors='coerce') * 1.01387  # bhp -> hp
data['Max Power (rpm)'] = pd.to_numeric(
    data['Max Power'].str.extract('@\s*(\d+)')[0], errors='coerce')

data['Max Torque (Nm)'] = pd.to_numeric(
    data['Max Torque'].str.extract('(\d+\.?\d*)')[0], errors='coerce')
data['Max Torque (rpm)'] = pd.to_numeric(
    data['Max Torque'].str.extract('@\s*(\d+)')[0], errors='coerce')

# convert owner to numeric, NaN for unknown
data['Owner'].replace('UnRegistered Car', np.nan, inplace=True)
owner_mapping = {
    'First': 1,
    'Second': 2,
    'Third': 3,
    'Fourth': 4,
    '4 or More': 5
}
data['Owner'] = data['Owner'].map(owner_mapping)

# rename columns to corect names
data.rename(
    columns={
        'Make': 'Brand',
        'Price': 'Price (USD)',
        'Kilometer': 'Mileage (km)',
        'Engine': 'Engine Capacity (cc)'
    },
    inplace=True)

# delete useless columns
data.drop(
    columns=[
        'Location',
        'Length',
        'Width',
        'Height',
        'Max Power',
        'Max Torque'
    ],
    inplace=True)

# %%
data.head()
# Out:
#            Brand                            Model   Price (USD)  Year  \
# 0          Honda              Amaze 1.2 VX i-VTEC   6213.090551  2017
# 1  Maruti Suzuki                  Swift DZire VDI   5536.417323  2014
# 2        Hyundai             i10 Magna 1.2 Kappa2   2706.692913  2011
# 3         Toyota                         Glanza G   9830.216535  2019
# 4         Toyota  Innova 2.4 VX 7 STR [2016-2020]  23991.141732  2018
#
#    Mileage (km) Fuel Type Transmission   Color  Owner Seller Type  \
# 0         87150    Petrol       Manual    Grey    1.0   Corporate
# 1         75000    Diesel       Manual   White    2.0  Individual
# 2         67000    Petrol       Manual  Maroon    1.0  Individual
# 3         37500    Petrol       Manual     Red    1.0  Individual
# 4         69000    Diesel       Manual    Grey    1.0  Individual
#
#    Engine Capacity (cc) Drivetrain  Seating Capacity  Fuel Tank Capacity  \
# 0                1198.0        FWD               5.0                35.0
# 1                1248.0        FWD               5.0                42.0
# 2                1197.0        FWD               5.0                35.0
# 3                1197.0        FWD               5.0                37.0
# 4                2393.0        RWD               7.0                55.0
#
#    Max Power (hp)  Max Power (rpm)  Max Torque (Nm)  Max Torque (rpm)
# 0        88.20669           6000.0         109.0000            4500.0
# 1        75.02638           4000.0         190.0000            2000.0
# 2        80.09573           6000.0         112.7619            4000.0
# 3        83.13734           6000.0         113.0000            4200.0
# 4       150.05276           3400.0         343.0000            1400.0

# %%
data.describe()
# Out:
#          Price (USD)         Year  Mileage (km)        Owner  \
# count    2059.000000  2059.000000  2.059000e+03  2038.000000
# mean    20952.161620  2016.425449  5.422471e+04     1.230618
# std     29772.153487     3.363564  5.736172e+04     0.483203
# min       602.854331  1988.000000  0.000000e+00     1.000000
# 25%      5967.015256  2014.000000  2.900000e+04     1.000000
# 50%     10150.098425  2017.000000  5.000000e+04     1.000000
# 75%     23683.562992  2019.000000  7.200000e+04     1.000000
# max    430610.236220  2022.000000  2.000000e+06     5.000000
#
#        Engine Capacity (cc)  Seating Capacity  Fuel Tank Capacity  \
# count           1979.000000       1995.000000         1946.000000
# mean            1692.575543          5.306266           52.002210
# std              643.736294          0.822170           15.110198
# min              624.000000          2.000000           15.000000
# 25%             1197.000000          5.000000           41.250000
# 50%             1498.000000          5.000000           50.000000
# 75%             1995.000000          5.000000           60.000000
# max             6592.000000          8.000000          105.000000
#
#        Max Power (hp)  Max Power (rpm)  Max Torque (Nm)  Max Torque (rpm)
# count     1979.000000      1975.000000      1979.000000       1979.000000
# mean       131.409489      4835.093671       245.851019       2619.545225
# std         65.976371      1097.368548       140.465731       1206.314770
# min         35.485450      2910.000000        48.000000        150.000000
# 25%         84.151210      4000.000000       115.000000       1600.000000
# 50%        117.608920      4200.000000       200.000000       1900.000000
# 75%        173.371770      6000.000000       350.000000       4000.000000
# max        669.154200      8250.000000       780.000000       6500.000000

# %%
reg = setup(data, target='Price (USD)', session_id=123, experiment_name='cars')
# Out:
# <style type="text/css">
# #T_f0aa4_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f0aa4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f0aa4_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f0aa4_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f0aa4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f0aa4_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f0aa4_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_f0aa4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f0aa4_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f0aa4_row1_col1" class="data row1 col1" >Price (USD)</td>
#     </tr>
#     <tr>
#       <th id="T_f0aa4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f0aa4_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_f0aa4_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_f0aa4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f0aa4_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_f0aa4_row3_col1" class="data row3 col1" >(2059, 18)</td>
#     </tr>
#     <tr>
#       <th id="T_f0aa4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f0aa4_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_f0aa4_row4_col1" class="data row4 col1" >(2059, 45)</td>
#     </tr>
#     <tr>
#       <th id="T_f0aa4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f0aa4_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_f0aa4_row5_col1" class="data row5 col1" >(1441, 45)</td>
#     </tr>
#     <tr>
#       <th id="T_f0aa4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f0aa4_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_f0aa4_row6_col1" class="data row6 col1" >(618, 45)</td>
#     </tr>
#     <tr>
#       <th id="T_f0aa4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f0aa4_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_f0aa4_row7_col1" class="data row7 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_f0aa4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f0aa4_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_f0aa4_row8_col1" class="data row8 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_f0aa4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f0aa4_row9_col0" class="data row9 col0" >Rows with missing values</td>
#       <td id="T_f0aa4_row9_col1" class="data row9 col1" >10.0%</td>
#     </tr>
#     <tr>
#       <th id="T_f0aa4_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f0aa4_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_f0aa4_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f0aa4_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f0aa4_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_f0aa4_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_f0aa4_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f0aa4_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_f0aa4_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_f0aa4_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f0aa4_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_f0aa4_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_f0aa4_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f0aa4_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_f0aa4_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_f0aa4_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f0aa4_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_f0aa4_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f0aa4_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f0aa4_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_f0aa4_row16_col1" class="data row16 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_f0aa4_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f0aa4_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_f0aa4_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_f0aa4_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f0aa4_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_f0aa4_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_f0aa4_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_f0aa4_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_f0aa4_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f0aa4_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_f0aa4_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_f0aa4_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f0aa4_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_f0aa4_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_f0aa4_row21_col1" class="data row21 col1" >cars</td>
#     </tr>
#     <tr>
#       <th id="T_f0aa4_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_f0aa4_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_f0aa4_row22_col1" class="data row22 col1" >d9b3</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model = compare_models(fold=2)
# Out:
# <style type="text/css">
# #T_c35ca th {
#   text-align: left;
# }
# #T_c35ca_row0_col0, #T_c35ca_row1_col0, #T_c35ca_row1_col1, #T_c35ca_row1_col2, #T_c35ca_row1_col3, #T_c35ca_row1_col4, #T_c35ca_row1_col5, #T_c35ca_row1_col6, #T_c35ca_row2_col0, #T_c35ca_row2_col1, #T_c35ca_row2_col2, #T_c35ca_row2_col3, #T_c35ca_row2_col4, #T_c35ca_row2_col5, #T_c35ca_row2_col6, #T_c35ca_row3_col0, #T_c35ca_row3_col1, #T_c35ca_row3_col2, #T_c35ca_row3_col3, #T_c35ca_row3_col4, #T_c35ca_row3_col5, #T_c35ca_row3_col6, #T_c35ca_row4_col0, #T_c35ca_row4_col1, #T_c35ca_row4_col2, #T_c35ca_row4_col3, #T_c35ca_row4_col4, #T_c35ca_row4_col5, #T_c35ca_row4_col6, #T_c35ca_row5_col0, #T_c35ca_row5_col1, #T_c35ca_row5_col2, #T_c35ca_row5_col3, #T_c35ca_row5_col4, #T_c35ca_row5_col5, #T_c35ca_row5_col6, #T_c35ca_row6_col0, #T_c35ca_row6_col1, #T_c35ca_row6_col2, #T_c35ca_row6_col3, #T_c35ca_row6_col4, #T_c35ca_row6_col5, #T_c35ca_row6_col6, #T_c35ca_row7_col0, #T_c35ca_row7_col1, #T_c35ca_row7_col2, #T_c35ca_row7_col3, #T_c35ca_row7_col4, #T_c35ca_row7_col5, #T_c35ca_row7_col6, #T_c35ca_row8_col0, #T_c35ca_row8_col1, #T_c35ca_row8_col2, #T_c35ca_row8_col3, #T_c35ca_row8_col4, #T_c35ca_row8_col5, #T_c35ca_row8_col6, #T_c35ca_row9_col0, #T_c35ca_row9_col1, #T_c35ca_row9_col2, #T_c35ca_row9_col3, #T_c35ca_row9_col4, #T_c35ca_row9_col5, #T_c35ca_row9_col6, #T_c35ca_row10_col0, #T_c35ca_row10_col1, #T_c35ca_row10_col2, #T_c35ca_row10_col3, #T_c35ca_row10_col4, #T_c35ca_row10_col5, #T_c35ca_row10_col6, #T_c35ca_row11_col0, #T_c35ca_row11_col1, #T_c35ca_row11_col2, #T_c35ca_row11_col3, #T_c35ca_row11_col4, #T_c35ca_row11_col5, #T_c35ca_row11_col6, #T_c35ca_row12_col0, #T_c35ca_row12_col1, #T_c35ca_row12_col2, #T_c35ca_row12_col3, #T_c35ca_row12_col4, #T_c35ca_row12_col5, #T_c35ca_row12_col6, #T_c35ca_row13_col0, #T_c35ca_row13_col1, #T_c35ca_row13_col2, #T_c35ca_row13_col3, #T_c35ca_row13_col4, #T_c35ca_row13_col5, #T_c35ca_row13_col6, #T_c35ca_row14_col0, #T_c35ca_row14_col1, #T_c35ca_row14_col2, #T_c35ca_row14_col3, #T_c35ca_row14_col4, #T_c35ca_row14_col5, #T_c35ca_row14_col6, #T_c35ca_row15_col0, #T_c35ca_row15_col1, #T_c35ca_row15_col2, #T_c35ca_row15_col3, #T_c35ca_row15_col4, #T_c35ca_row15_col5, #T_c35ca_row15_col6, #T_c35ca_row16_col0, #T_c35ca_row16_col1, #T_c35ca_row16_col2, #T_c35ca_row16_col3, #T_c35ca_row16_col4, #T_c35ca_row16_col5, #T_c35ca_row16_col6, #T_c35ca_row17_col0, #T_c35ca_row17_col1, #T_c35ca_row17_col2, #T_c35ca_row17_col3, #T_c35ca_row17_col4, #T_c35ca_row17_col5, #T_c35ca_row17_col6 {
#   text-align: left;
# }
# #T_c35ca_row0_col1, #T_c35ca_row0_col2, #T_c35ca_row0_col3, #T_c35ca_row0_col4, #T_c35ca_row0_col5, #T_c35ca_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_c35ca_row0_col7, #T_c35ca_row1_col7, #T_c35ca_row2_col7, #T_c35ca_row3_col7, #T_c35ca_row4_col7, #T_c35ca_row5_col7, #T_c35ca_row6_col7, #T_c35ca_row7_col7, #T_c35ca_row8_col7, #T_c35ca_row9_col7, #T_c35ca_row10_col7, #T_c35ca_row11_col7, #T_c35ca_row12_col7, #T_c35ca_row13_col7, #T_c35ca_row14_col7, #T_c35ca_row15_col7, #T_c35ca_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_c35ca_row16_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_c35ca">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c35ca_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c35ca_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_c35ca_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_c35ca_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_c35ca_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_c35ca_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_c35ca_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_c35ca_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c35ca_level0_row0" class="row_heading level0 row0" >knn</th>
#       <td id="T_c35ca_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_c35ca_row0_col1" class="data row0 col1" >8933.9785</td>
#       <td id="T_c35ca_row0_col2" class="data row0 col2" >478810144.0000</td>
#       <td id="T_c35ca_row0_col3" class="data row0 col3" >21880.7305</td>
#       <td id="T_c35ca_row0_col4" class="data row0 col4" >0.4568</td>
#       <td id="T_c35ca_row0_col5" class="data row0 col5" >0.5928</td>
#       <td id="T_c35ca_row0_col6" class="data row0 col6" >0.5531</td>
#       <td id="T_c35ca_row0_col7" class="data row0 col7" >1.1600</td>
#     </tr>
#     <tr>
#       <th id="T_c35ca_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_c35ca_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_c35ca_row1_col1" class="data row1 col1" >11299.5526</td>
#       <td id="T_c35ca_row1_col2" class="data row1 col2" >590489654.4009</td>
#       <td id="T_c35ca_row1_col3" class="data row1 col3" >24299.4626</td>
#       <td id="T_c35ca_row1_col4" class="data row1 col4" >0.3300</td>
#       <td id="T_c35ca_row1_col5" class="data row1 col5" >0.8002</td>
#       <td id="T_c35ca_row1_col6" class="data row1 col6" >0.9959</td>
#       <td id="T_c35ca_row1_col7" class="data row1 col7" >0.3000</td>
#     </tr>
#     <tr>
#       <th id="T_c35ca_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_c35ca_row2_col0" class="data row2 col0" >Extra Trees Regressor</td>
#       <td id="T_c35ca_row2_col1" class="data row2 col1" >10861.9375</td>
#       <td id="T_c35ca_row2_col2" class="data row2 col2" >595436383.5719</td>
#       <td id="T_c35ca_row2_col3" class="data row2 col3" >24401.3727</td>
#       <td id="T_c35ca_row2_col4" class="data row2 col4" >0.3244</td>
#       <td id="T_c35ca_row2_col5" class="data row2 col5" >0.7842</td>
#       <td id="T_c35ca_row2_col6" class="data row2 col6" >0.9517</td>
#       <td id="T_c35ca_row2_col7" class="data row2 col7" >0.2050</td>
#     </tr>
#     <tr>
#       <th id="T_c35ca_level0_row3" class="row_heading level0 row3" >gbr</th>
#       <td id="T_c35ca_row3_col0" class="data row3 col0" >Gradient Boosting Regressor</td>
#       <td id="T_c35ca_row3_col1" class="data row3 col1" >11021.7398</td>
#       <td id="T_c35ca_row3_col2" class="data row3 col2" >600152636.9406</td>
#       <td id="T_c35ca_row3_col3" class="data row3 col3" >24497.1623</td>
#       <td id="T_c35ca_row3_col4" class="data row3 col4" >0.3190</td>
#       <td id="T_c35ca_row3_col5" class="data row3 col5" >0.7942</td>
#       <td id="T_c35ca_row3_col6" class="data row3 col6" >0.9768</td>
#       <td id="T_c35ca_row3_col7" class="data row3 col7" >0.1900</td>
#     </tr>
#     <tr>
#       <th id="T_c35ca_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_c35ca_row4_col0" class="data row4 col0" >AdaBoost Regressor</td>
#       <td id="T_c35ca_row4_col1" class="data row4 col1" >11737.7015</td>
#       <td id="T_c35ca_row4_col2" class="data row4 col2" >645414207.5858</td>
#       <td id="T_c35ca_row4_col3" class="data row4 col3" >25403.1343</td>
#       <td id="T_c35ca_row4_col4" class="data row4 col4" >0.2677</td>
#       <td id="T_c35ca_row4_col5" class="data row4 col5" >0.8490</td>
#       <td id="T_c35ca_row4_col6" class="data row4 col6" >1.0720</td>
#       <td id="T_c35ca_row4_col7" class="data row4 col7" >0.1200</td>
#     </tr>
#     <tr>
#       <th id="T_c35ca_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_c35ca_row5_col0" class="data row5 col0" >Random Forest Regressor</td>
#       <td id="T_c35ca_row5_col1" class="data row5 col1" >11629.1381</td>
#       <td id="T_c35ca_row5_col2" class="data row5 col2" >654217926.7622</td>
#       <td id="T_c35ca_row5_col3" class="data row5 col3" >25577.0322</td>
#       <td id="T_c35ca_row5_col4" class="data row5 col4" >0.2577</td>
#       <td id="T_c35ca_row5_col5" class="data row5 col5" >0.8392</td>
#       <td id="T_c35ca_row5_col6" class="data row5 col6" >1.0501</td>
#       <td id="T_c35ca_ro

# %%
models()
# Out:
#                                        Name  \
# ID
# lr                        Linear Regression
# lasso                      Lasso Regression
# ridge                      Ridge Regression
# en                              Elastic Net
# lar                  Least Angle Regression
# llar           Lasso Least Angle Regression
# omp             Orthogonal Matching Pursuit
# br                           Bayesian Ridge
# ard       Automatic Relevance Determination
# par            Passive Aggressive Regressor
# ransac              Random Sample Consensus
# tr                       TheilSen Regressor
# huber                       Huber Regressor
# kr                             Kernel Ridge
# svm               Support Vector Regression
# knn                   K Neighbors Regressor
# dt                  Decision Tree Regressor
# rf                  Random Forest Regressor
# et                    Extra Trees Regressor
# ada                      AdaBoost Regressor
# gbr             Gradient Boosting Regressor
# mlp                           MLP Regressor
# lightgbm    Light Gradient Boosting Machine
# dummy                       Dummy Regressor
#
#                                                   Reference  Turbo
# ID
# lr              sklearn.linear_model._base.LinearRegression   True
# lasso        sklearn.linear_model._coordinate_descent.Lasso   True
# ridge                     sklearn.linear_model._ridge.Ridge   True
# en        sklearn.linear_model._coordinate_descent.Elast...   True
# lar                  sklearn.linear_model._least_angle.Lars   True
# llar            sklearn.linear_model._least_angle.LassoLars   True
# omp       sklearn.linear_model._omp.OrthogonalMatchingPu...   True
# br                sklearn.linear_model._bayes.BayesianRidge   True
# ard               sklearn.linear_model._bayes.ARDRegression  False
# par       sklearn.linear_model._passive_aggressive.Passi...   True
# ransac         sklearn.linear_model._ransac.RANSACRegressor  False
# tr        sklearn.linear_model._theil_sen.TheilSenRegressor  False
# huber            sklearn.linear_model._huber.HuberRegressor   True
# kr                         sklearn.kernel_ridge.KernelRidge  False
# svm                                sklearn.svm._classes.SVR  False
# knn       sklearn.neighbors._regression.KNeighborsRegressor   True
# dt              sklearn.tree._classes.DecisionTreeRegressor   True
# rf           sklearn.ensemble._forest.RandomForestRegressor   True
# et             sklearn.ensemble._forest.ExtraTreesRegressor   True
# ada       sklearn.ensemble._weight_boosting.AdaBoostRegr...   True
# gbr          sklearn.ensemble._gb.GradientBoostingRegressor   True
# mlp       sklearn.neural_network._multilayer_perceptron....  False
# lightgbm                     lightgbm.sklearn.LGBMRegressor   True
# dummy                          sklearn.dummy.DummyRegressor   True

# %%
knn_model = create_model('knn')
# Out:
# <style type="text/css">
# #T_bdd0c_row10_col0, #T_bdd0c_row10_col1, #T_bdd0c_row10_col2, #T_bdd0c_row10_col3, #T_bdd0c_row10_col4, #T_bdd0c_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_bdd0c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bdd0c_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_bdd0c_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_bdd0c_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_bdd0c_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_bdd0c_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_bdd0c_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bdd0c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bdd0c_row0_col0" class="data row0 col0" >5788.4873</td>
#       <td id="T_bdd0c_row0_col1" class="data row0 col1" >96094488.0000</td>
#       <td id="T_bdd0c_row0_col2" class="data row0 col2" >9802.7793</td>
#       <td id="T_bdd0c_row0_col3" class="data row0 col3" >0.7939</td>
#       <td id="T_bdd0c_row0_col4" class="data row0 col4" >0.4763</td>
#       <td id="T_bdd0c_row0_col5" class="data row0 col5" >0.4466</td>
#     </tr>
#     <tr>
#       <th id="T_bdd0c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bdd0c_row1_col0" class="data row1 col0" >7380.8818</td>
#       <td id="T_bdd0c_row1_col1" class="data row1 col1" >303727744.0000</td>
#       <td id="T_bdd0c_row1_col2" class="data row1 col2" >17427.7871</td>
#       <td id="T_bdd0c_row1_col3" class="data row1 col3" >0.5589</td>
#       <td id="T_bdd0c_row1_col4" class="data row1 col4" >0.5703</td>
#       <td id="T_bdd0c_row1_col5" class="data row1 col5" >0.5121</td>
#     </tr>
#     <tr>
#       <th id="T_bdd0c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bdd0c_row2_col0" class="data row2 col0" >11235.6621</td>
#       <td id="T_bdd0c_row2_col1" class="data row2 col1" >810704000.0000</td>
#       <td id="T_bdd0c_row2_col2" class="data row2 col2" >28472.8652</td>
#       <td id="T_bdd0c_row2_col3" class="data row2 col3" >0.3541</td>
#       <td id="T_bdd0c_row2_col4" class="data row2 col4" >0.5678</td>
#       <td id="T_bdd0c_row2_col5" class="data row2 col5" >0.4297</td>
#     </tr>
#     <tr>
#       <th id="T_bdd0c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bdd0c_row3_col0" class="data row3 col0" >9983.2197</td>
#       <td id="T_bdd0c_row3_col1" class="data row3 col1" >881151232.0000</td>
#       <td id="T_bdd0c_row3_col2" class="data row3 col2" >29684.1914</td>
#       <td id="T_bdd0c_row3_col3" class="data row3 col3" >0.3519</td>
#       <td id="T_bdd0c_row3_col4" class="data row3 col4" >0.6065</td>
#       <td id="T_bdd0c_row3_col5" class="data row3 col5" >0.5511</td>
#     </tr>
#     <tr>
#       <th id="T_bdd0c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bdd0c_row4_col0" class="data row4 col0" >6059.2153</td>
#       <td id="T_bdd0c_row4_col1" class="data row4 col1" >166986528.0000</td>
#       <td id="T_bdd0c_row4_col2" class="data row4 col2" >12922.3271</td>
#       <td id="T_bdd0c_row4_col3" class="data row4 col3" >0.7246</td>
#       <td id="T_bdd0c_row4_col4" class="data row4 col4" >0.5246</td>
#       <td id="T_bdd0c_row4_col5" class="data row4 col5" >0.5434</td>
#     </tr>
#     <tr>
#       <th id="T_bdd0c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bdd0c_row5_col0" class="data row5 col0" >5973.6748</td>
#       <td id="T_bdd0c_row5_col1" class="data row5 col1" >91787680.0000</td>
#       <td id="T_bdd0c_row5_col2" class="data row5 col2" >9580.5889</td>
#       <td id="T_bdd0c_row5_col3" class="data row5 col3" >0.7535</td>
#       <td id="T_bdd0c_row5_col4" class="data row5 col4" >0.5719</td>
#       <td id="T_bdd0c_row5_col5" class="data row5 col5" >0.5890</td>
#     </tr>
#     <tr>
#       <th id="T_bdd0c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_bdd0c_row6_col0" class="data row6 col0" >7234.4399</td>
#       <td id="T_bdd0c_row6_col1" class="data row6 col1" >352723168.0000</td>
#       <td id="T_bdd0c_row6_col2" class="data row6 col2" >18780.9258</td>
#       <td id="T_bdd0c_row6_col3" class="data row6 col3" >0.5744</td>
#       <td id="T_bdd0c_row6_col4" class="data row6 col4" >0.5474</td>
#       <td id="T_bdd0c_row6_col5" class="data row6 col5" >0.5308</td>
#     </tr>
#     <tr>
#       <th id="T_bdd0c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_bdd0c_row7_col0" class="data row7 col0" >6216.6953</td>
#       <td id="T_bdd0c_row7_col1" class="data row7 col1" >117242432.0000</td>
#       <td id="T_bdd0c_row7_col2" class="data row7 col2" >10827.8545</td>
#       <td id="T_bdd0c_row7_col3" class="data row7 col3" >0.7273</td>
#       <td id="T_bdd0c_row7_col4" class="data row7 col4" >0.4553</td>
#       <td id="T_bdd0c_row7_col5" class="data row7 col5" >0.4181</td>
#     </tr>
#     <tr>
#       <th id="T_bdd0c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_bdd0c_row8_col0" class="data row8 col0" >12507.8262</td>
#       <td id="T_bdd0c_row8_col1" class="data row8 col1" >1410906624.0000</td>
#       <td id="T_bdd0c_row8_col2" class="data row8 col2" >37562.0352</td>
#       <td id="T_bdd0c_row8_col3" class="data row8 col3" >0.2833</td>
#       <td id="T_bdd0c_row8_col4" class="data row8 col4" >0.6015</td>
#       <td id="T_bdd0c_row8_col5" class="data row8 col5" >0.4858</td>
#     </tr>
#     <tr>
#       <th id="T_bdd0c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_bdd0c_row9_col0" class="data row9 col0" >7396.4316</td>
#       <td id="T_bdd0c_row9_col1" class="data row9 col1" >197816416.0000</td>
#       <td id="T_bdd0c_row9_col2" class="data row9 col2" >14064.7227</td>
#       <td id="T_bdd0c_row9_col3" class="data row9 col3" >0.7361</td>
#       <td id="T_bdd0c_row9_col4" class="data row9 col4" >0.5519</td>
#       <td id="T_bdd0c_row9_col5" class="data row9 col5" >0.5371</td>
#     </tr>
#     <tr>
#       <th id="T_bdd0c_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_bdd0c_row10_col0" class="data row10 col0" >7977.6534</td>
#       <td id="T_bdd0c_row10_col1" class="data row10 col1" >442914031.2000</td>
#       <td id="T_bdd0c_row10_col2" class="data row10 col2" >18912.6077</td>
#       <td id="T_bdd0c_row10_col3" class="data row10 col3" >0.5858</td>
#       <td id="T_bdd0c_row10_col4" class="data row10 col4" >0.5473</td>
#       <td id="T_bdd0c_row10_col5" class="data row10 col5" >0.5044</td>
#     </tr>
#     <tr>
#       <th id="T_bdd0c_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_bdd0c_row11_col0" class="data row11 col0" >2280.2513</td>
#       <td id="T_bdd0c_row11_col1" class="data row11 col1" >421625723.5934</td>
#       <td id="T_bdd0c_row11_col2" class="data row11 col2" >9231.8630</td>
#       <td id="T_bdd0c_row11_col3" class="data row11 col3" >0.1828</td>
#       <td id="T_bdd0c_row11_col4" class="data row11 col4" >0.0470</td>
#       <td id="T_bdd0c_row11_col5" class="data row11 col5" >0.0542</td>
#     </tr>
#   </tbody>
# </table>

# %%
tuned_knn_model = tune_model(knn_model, n_iter = 50, optimize = 'R2')
# Out:
# <style type="text/css">
# #T_1143c_row10_col0, #T_1143c_row10_col1, #T_1143c_row10_col2, #T_1143c_row10_col3, #T_1143c_row10_col4, #T_1143c_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_1143c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1143c_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_1143c_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_1143c_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_1143c_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_1143c_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_1143c_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1143c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1143c_row0_col0" class="data row0 col0" >5022.2010</td>
#       <td id="T_1143c_row0_col1" class="data row0 col1" >75673647.4932</td>
#       <td id="T_1143c_row0_col2" class="data row0 col2" >8699.0601</td>
#       <td id="T_1143c_row0_col3" class="data row0 col3" >0.8377</td>
#       <td id="T_1143c_row0_col4" class="data row0 col4" >0.4318</td>
#       <td id="T_1143c_row0_col5" class="data row0 col5" >0.4013</td>
#     </tr>
#     <tr>
#       <th id="T_1143c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1143c_row1_col0" class="data row1 col0" >6953.2895</td>
#       <td id="T_1143c_row1_col1" class="data row1 col1" >273822609.1784</td>
#       <td id="T_1143c_row1_col2" class="data row1 col2" >16547.5862</td>
#       <td id="T_1143c_row1_col3" class="data row1 col3" >0.6024</td>
#       <td id="T_1143c_row1_col4" class="data row1 col4" >0.5207</td>
#       <td id="T_1143c_row1_col5" class="data row1 col5" >0.4800</td>
#     </tr>
#     <tr>
#       <th id="T_1143c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1143c_row2_col0" class="data row2 col0" >10502.5349</td>
#       <td id="T_1143c_row2_col1" class="data row2 col1" >738896740.0227</td>
#       <td id="T_1143c_row2_col2" class="data row2 col2" >27182.6551</td>
#       <td id="T_1143c_row2_col3" class="data row2 col3" >0.4113</td>
#       <td id="T_1143c_row2_col4" class="data row2 col4" >0.5032</td>
#       <td id="T_1143c_row2_col5" class="data row2 col5" >0.3589</td>
#     </tr>
#     <tr>
#       <th id="T_1143c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1143c_row3_col0" class="data row3 col0" >9715.4080</td>
#       <td id="T_1143c_row3_col1" class="data row3 col1" >850536874.8971</td>
#       <td id="T_1143c_row3_col2" class="data row3 col2" >29163.9653</td>
#       <td id="T_1143c_row3_col3" class="data row3 col3" >0.3744</td>
#       <td id="T_1143c_row3_col4" class="data row3 col4" >0.5601</td>
#       <td id="T_1143c_row3_col5" class="data row3 col5" >0.5003</td>
#     </tr>
#     <tr>
#       <th id="T_1143c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1143c_row4_col0" class="data row4 col0" >5752.0365</td>
#       <td id="T_1143c_row4_col1" class="data row4 col1" >142149612.1239</td>
#       <td id="T_1143c_row4_col2" class="data row4 col2" >11922.6512</td>
#       <td id="T_1143c_row4_col3" class="data row4 col3" >0.7656</td>
#       <td id="T_1143c_row4_col4" class="data row4 col4" >0.4926</td>
#       <td id="T_1143c_row4_col5" class="data row4 col5" >0.4978</td>
#     </tr>
#     <tr>
#       <th id="T_1143c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1143c_row5_col0" class="data row5 col0" >5586.8526</td>
#       <td id="T_1143c_row5_col1" class="data row5 col1" >88794614.4546</td>
#       <td id="T_1143c_row5_col2" class="data row5 col2" >9423.0894</td>
#       <td id="T_1143c_row5_col3" class="data row5 col3" >0.7615</td>
#       <td id="T_1143c_row5_col4" class="data row5 col4" >0.5242</td>
#       <td id="T_1143c_row5_col5" class="data row5 col5" >0.5272</td>
#     </tr>
#     <tr>
#       <th id="T_1143c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1143c_row6_col0" class="data row6 col0" >6609.0240</td>
#       <td id="T_1143c_row6_col1" class="data row6 col1" >300634226.3328</td>
#       <td id="T_1143c_row6_col2" class="data row6 col2" >17338.8069</td>
#       <td id="T_1143c_row6_col3" class="data row6 col3" >0.6372</td>
#       <td id="T_1143c_row6_col4" class="data row6 col4" >0.5077</td>
#       <td id="T_1143c_row6_col5" class="data row6 col5" >0.5014</td>
#     </tr>
#     <tr>
#       <th id="T_1143c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1143c_row7_col0" class="data row7 col0" >5846.3038</td>
#       <td id="T_1143c_row7_col1" class="data row7 col1" >110668233.4799</td>
#       <td id="T_1143c_row7_col2" class="data row7 col2" >10519.8970</td>
#       <td id="T_1143c_row7_col3" class="data row7 col3" >0.7426</td>
#       <td id="T_1143c_row7_col4" class="data row7 col4" >0.4206</td>
#       <td id="T_1143c_row7_col5" class="data row7 col5" >0.3758</td>
#     </tr>
#     <tr>
#       <th id="T_1143c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1143c_row8_col0" class="data row8 col0" >11627.5411</td>
#       <td id="T_1143c_row8_col1" class="data row8 col1" >1348605201.7732</td>
#       <td id="T_1143c_row8_col2" class="data row8 col2" >36723.3604</td>
#       <td id="T_1143c_row8_col3" class="data row8 col3" >0.3150</td>
#       <td id="T_1143c_row8_col4" class="data row8 col4" >0.5409</td>
#       <td id="T_1143c_row8_col5" class="data row8 col5" >0.4019</td>
#     </tr>
#     <tr>
#       <th id="T_1143c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1143c_row9_col0" class="data row9 col0" >7153.6513</td>
#       <td id="T_1143c_row9_col1" class="data row9 col1" >200972143.3718</td>
#       <td id="T_1143c_row9_col2" class="data row9 col2" >14176.4644</td>
#       <td id="T_1143c_row9_col3" class="data row9 col3" >0.7319</td>
#       <td id="T_1143c_row9_col4" class="data row9 col4" >0.4982</td>
#       <td id="T_1143c_row9_col5" class="data row9 col5" >0.4746</td>
#     </tr>
#     <tr>
#       <th id="T_1143c_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_1143c_row10_col0" class="data row10 col0" >7476.8843</td>
#       <td id="T_1143c_row10_col1" class="data row10 col1" >413075390.3128</td>
#       <td id="T_1143c_row10_col2" class="data row10 col2" >18169.7536</td>
#       <td id="T_1143c_row10_col3" class="data row10 col3" >0.6179</td>
#       <td id="T_1143c_row10_col4" class="data row10 col4" >0.5000</td>
#       <td id="T_1143c_row10_col5" class="data row10 col5" >0.4519</td>
#     </tr>
#     <tr>
#       <th id="T_1143c_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_1143c_row11_col0" class="data row11 col0" >2185.3352</td>
#       <td id="T_1143c_row11_col1" class="data row11 col1" >404180540.5714</td>
#       <td id="T_1143c_row11_col2" class="data row11 col2" >9106.8899</td>
#       <td id="T_1143c_row11_col3" class="data row11 col3" >0.1771</td>
#       <td id="T_1143c_row11_col4" class="data row11 col4" >0.0417</td>
#       <td id="T_1143c_row11_col5" class="data row11 col5" >0.0578</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 50 candidates, totalling 500 fits

# %%
evaluate_model(tuned_knn_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
predictions = predict_model(tuned_knn_model, data=data)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f2247">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f2247_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f2247_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_f2247_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_f2247_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_f2247_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_f2247_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_f2247_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2247_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f2247_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_f2247_row0_col1" class="data row0 col1" >2268.8557</td>
#       <td id="T_f2247_row0_col2" class="data row0 col2" >142314849.6847</td>
#       <td id="T_f2247_row0_col3" class="data row0 col3" >11929.5788</td>
#       <td id="T_f2247_row0_col4" class="data row0 col4" >0.8394</td>
#       <td id="T_f2247_row0_col5" class="data row0 col5" >0.2684</td>
#       <td id="T_f2247_row0_col6" class="data row0 col6" >0.1297</td>
#     </tr>
#   </tbody>
# </table>

# %%
predictions.head()
# Out:
#            Brand                            Model  Year  Mileage (km)  \
# 0          Honda              Amaze 1.2 VX i-VTEC  2017         87150
# 1  Maruti Suzuki                  Swift DZire VDI  2014         75000
# 2        Hyundai             i10 Magna 1.2 Kappa2  2011         67000
# 3         Toyota                         Glanza G  2019         37500
# 4         Toyota  Innova 2.4 VX 7 STR [2016-2020]  2018         69000
#
#   Fuel Type Transmission   Color  Owner Seller Type  Engine Capacity (cc)  \
# 0    Petrol       Manual    Grey    1.0   Corporate                1198.0
# 1    Diesel       Manual   White    2.0  Individual                1248.0
# 2    Petrol       Manual  Maroon    1.0  Individual                1197.0
# 3    Petrol       Manual     Red    1.0  Individual                1197.0
# 4    Diesel       Manual    Grey    1.0  Individual                2393.0
#
#   Drivetrain  Seating Capacity  Fuel Tank Capacity  Max Power (hp)  \
# 0        FWD               5.0                35.0       88.206688
# 1        FWD               5.0                42.0       75.026382
# 2        FWD               5.0                35.0       80.095734
# 3        FWD               5.0                37.0       83.137337
# 4        RWD               7.0                55.0      150.052765
#
#    Max Power (rpm)  Max Torque (Nm)  Max Torque (rpm)   Price (USD)  \
# 0           6000.0       109.000000            4500.0   6213.090332
# 1           4000.0       190.000000            2000.0   5536.417480
# 2           6000.0       112.761902            4000.0   2706.692871
# 3           6000.0       113.000000            4200.0   9830.216797
# 4           3400.0       343.000000            1400.0  23991.142578
#
#    prediction_label
# 0       5797.223386
# 1       5536.417480
# 2       2706.692871
# 3       9830.216797
# 4      23991.142578

# %%
save_model(tuned_knn_model, model_name = 'deployment')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['Year', 'Mileage (km)', 'Owner',
#                                               'Engine Capacity (cc)',
#                                               'Seating Capacity',
#                                               'Fuel Tank Capacity',
#                                               'Max Power (hp)',
#                                               'Max Power (rpm)',
#                                               'Max Torque (Nm)',
#                                               'Max Torque (rpm)'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['Brand', 'Model', 'Fuel Ty...
#                                                                handle_missing='return_nan',
#                                                                use_cat_names=True))),
#                  ('rest_encoding',
#                   TransformerWrapper(include=['Brand', 'Model'],
#                                      transformer=TargetEncoder(cols=['Brand',
#                                                                      'Model'],
#                                                                handle_missing='return_nan'))),
#                  ('clean_column_names',
#                   TransformerWrapper(transformer=CleanColumnNames())),
#                  ('trained_model',
#                   KNeighborsRegressor(metric='manhattan', n_jobs=-1,
#                                       n_neighbors=13, weights='distance'))]),
#  'deployment.pkl')
